# %%
import pandas as pd
import numpy as np
import re

#!pip install geopandas
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# # Public Transit Data

# %%
# Public Bus Transit data
df_bus = pd.read_csv('Public_transit/cta-bus-stops-2.csv')

# Public Rails Transit data
df_rails = pd.read_csv('Public_transit/cta-rail-stops.csv')

# Geospatial file for Chicago community areas
geo_communities = 'Public_transit/community_areas_chicago.geojson'

# Load the community areas data
geo_community_areas = gpd.read_file(geo_communities)

# %%
geo_community_areas.head()
# Out:
#          community area     shape_area perimeter area_num_1 area_numbe  \
# 0          DOUGLAS    0  46004621.1581         0         35         35
# 1          OAKLAND    0  16913961.0408         0         36         36
# 2      FULLER PARK    0  19916704.8692         0         37         37
# 3  GRAND BOULEVARD    0  48492503.1554         0         38         38
# 4          KENWOOD    0  29071741.9283         0         39         39
#
#   comarea_id comarea      shape_len  \
# 0          0       0  31027.0545098
# 1          0       0  19565.5061533
# 2          0       0  25339.0897503
# 3          0       0  28196.8371573
# 4          0       0  23325.1679062
#
#                                             geometry
# 0  MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...
# 1  MULTIPOLYGON (((-87.59215 41.81693, -87.59231 ...
# 2  MULTIPOLYGON (((-87.62880 41.80189, -87.62879 ...
# 3  MULTIPOLYGON (((-87.60671 41.81681, -87.60670 ...
# 4  MULTIPOLYGON (((-87.59215 41.81693, -87.59215 ...

# %%
geo_community_areas.shape
# Out:
# (77, 10)

# %% [markdown]
# There are 77 community areas in Chicago, so this verifies we have all communities

# %%
df_bus.head()
# Out:
#    SYSTEMSTOP  OBJECTID                                       the_geom  \
# 0       11953       193   POINT (-87.54862703700002 41.72818418100002)
# 1        2723       194       POINT (-87.737227163 41.749111071000016)
# 2        1307       195  POINT (-87.74397362600001 41.924143016000016)
# 3        6696       196   POINT (-87.65929365400001 41.86931424800002)
# 4          22       197        POINT (-87.72780787099998 41.877006596)
#
#         STREET               CROSS_ST DIR POS ROUTESSTPG OWLROUTES     CITY  \
# 0  92ND STREET              BALTIMORE  EB  NS         95       NaN  CHICAGO
# 1  79TH STREET  KILPATRICK (east leg)  EB  NS         79       NaN  CHICAGO
# 2    FULLERTON             KILPATRICK  EB  NS         74       NaN  CHICAGO
# 3       TAYLOR                 THROOP  EB  NS        157       NaN  CHICAGO
# 4      JACKSON                 KARLOV  EB  FS        126       NaN  CHICAGO
#
#    STATUS                PUBLIC_NAM    POINT_X    POINT_Y
# 0       1   92nd Street & Baltimore -87.548627  41.728184
# 1       1  79th Street & Kilpatrick -87.737227  41.749111
# 2       1    Fullerton & Kilpatrick -87.743974  41.924143
# 3       1           Taylor & Throop -87.659294  41.869314
# 4       1          Jackson & Karlov -87.727808  41.877007

# %%
df_bus['STATUS'].value_counts()
# Out:
# 1    10760
# 2      220
# 6       66
# 5       21
# 3        7
# Name: STATUS, dtype: int64

# %%
# We only take the ones in service (status 1)
df_bus = df_bus[df_bus['STATUS'] == 1]

# %% [markdown]
# ## Match bus stop coordinates to the corresponding community areas

# %% [markdown]
# ### Helper function to convert to Point format

# %%
def string_to_point(point_str):
    # Extract coordinates using regex
    coords = re.findall(r"[-\d\.]+", point_str)
    # Convert strings to float and create Point geometry
    return Point(float(coords[0]), float(coords[1]))

# %%
df_bus[df_bus['OBJECTID'] == 193]['the_geom'][0]
# Out:
# 'POINT (-87.54862703700002 41.72818418100002)'

# %%
# List of all the coordinate locations of the bus stops
list_of_points = df_bus['the_geom'].tolist()
points = []

# Convert to Point datatype
for p in list_of_points:
    points.append(string_to_point(p))

# %%
gdf_points = gpd.GeoDataFrame(geometry=points, crs="EPSG:4326")
# gdf_point = gpd.GeoDataFrame([{'geometry': point}], crs="EPSG:4326")

# %%
points_in_community = gpd.sjoin(gdf_points, geo_community_areas, how="inner", op='within')
# Out:
# /Users/hassuni/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3377: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
points_in_community = points_in_community[['geometry', 'community', 'area_numbe']]
points_in_community
# Out:
#                          geometry      community area_numbe
# 0      POINT (-87.54863 41.72818)  SOUTH CHICAGO         46
# 62     POINT (-87.56119 41.75174)  SOUTH CHICAGO         46
# 114    POINT (-87.54823 41.75223)  SOUTH CHICAGO         46
# 262    POINT (-87.54699 41.73003)  SOUTH CHICAGO         46
# 272    POINT (-87.55430 41.73729)  SOUTH CHICAGO         46
# ...                           ...            ...        ...
# 9037   POINT (-87.84665 41.96824)          OHARE         76
# 9616   POINT (-87.83669 41.97576)          OHARE         76
# 9708   POINT (-87.84147 41.97942)          OHARE         76
# 10135  POINT (-87.84400 41.96635)          OHARE         76
# 10572  POINT (-87.84655 41.97682)          OHARE         76
#
# [10061 rows x 3 columns]

# %%
points_in_community['community'].value_counts()
# Out:
# AUSTIN                    405
# NEAR WEST SIDE            366
# WEST TOWN                 291
# NEAR NORTH SIDE           268
# GREATER GRAND CROSSING    257
#                          ...
# OHARE                      30
# OAKLAND                    25
# RIVERDALE                  23
# BURNSIDE                   19
# EDISON PARK                16
# Name: community, Length: 77, dtype: int64

# %% [markdown]
# ## Match train/rail stop coordinates to the corresponding community areas

# %%
df_rails
# Out:
#      STOP_ID DIRECTION_ID                      STOP_NAME    STATION_NAME  \
# 0      30082            E            Cicero (Loop-bound)          Cicero
# 1      30151            E      Central Park (Loop-bound)    Central Park
# 2      30184            W   Halsted/63rd (Ashland-bound)         Halsted
# 3      30044            N      Cumberland (O'Hare-bound)      Cumberland
# 4      30092            E          Racine (O'Hare-bound)          Racine
# ..       ...          ...                            ...             ...
# 295    30009            W          Cicero (Harlem-bound)          Cicero
# 296    30259            N        Montrose (O'Hare-bound)        Montrose
# 297    30125            N  North/Clybourn (Howard-bound)  North/Clybourn
# 298    30172            S       O'Hare (Forest Pk-bound)          O'Hare
# 299    30045            S   Cumberland (Forest Pk-bound)      Cumberland
#
#       STATION_DESCRIPTIVE_NAME  MAP_ID    ADA    RED   BLUE      G    BRN  \
# 0           Cicero (Pink Line)   40420   True  False  False  False  False
# 1     Central Park (Pink Line)   40780   True  False  False  False  False
# 2         Halsted (Green Line)   40940   True  False  False   True  False
# 3       Cumberland (Blue Line)   40230   True  False   True  False  False
# 4           Racine (Blue Line)   40470  False  False   True  False  False
# ..                         ...     ...    ...    ...    ...    ...    ...
# 295        Cicero (Green Line)   40480   True  False  False   True  False
# 296       Montrose (Blue Line)   41330  False  False   True  False  False
# 297  North/Clybourn (Red Line)   40650  False   True  False  False  False
# 298         O'Hare (Blue Line)   40890   True  False   True  False  False
# 299     Cumberland (Blue Line)   40230   True  False   True  False  False
#
#          P   Pexp      Y    Pnk      O                     Location
# 0    False  False  False   True  False       (41.85182, -87.745336)
# 1    False  False  False   True  False      (41.853839, -87.714842)
# 2    False  False  False  False  False      (41.778943, -87.644244)
# 3    False  False  False  False  False      (41.984246, -87.838028)
# 4    False  False  False  False  False       (41.87592, -87.659458)
# ..     ...    ...    ...    ...    ...                          ...
# 295  False  False  False  False  False      (41.886519, -87.744698)
# 296  False  False  False  False  False      (41.961539, -87.743574)
# 297  False  False  False  False  False      (41.910655, -87.649177)
# 298  False  False  False  False  False  (41.97766526, -87.90422307)
# 299  False  False  False  False  False      (41.984246, -87.838028)
#
# [300 rows x 17 columns]

# %%
# Function to convert location strings to Point objects
def string_to_point_rails(point_str):
    # Extract coordinates using regex
    coords = re.findall(r"[-\d\.]+", point_str)
    if len(coords) == 2:
        # Convert strings to float and create Point geometry
        return Point(float(coords[1]), float(coords[0]))
    return None

# %%
# List of all the coordinate locations of the bus stops
list_of_points = df_rails['Location'].tolist()
points = []

# Convert to Point datatype
for p in list_of_points:
    points.append(string_to_point_rails(p))

# %%
gdf_points = gpd.GeoDataFrame(geometry=points, crs="EPSG:4326")

# %%
points_in_community = gpd.sjoin(gdf_points, geo_community_areas, how="inner", op='within')
# Out:
# /Users/hassuni/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3377: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
points_in_community = points_in_community[['geometry', 'community', 'area_numbe']]
points_in_community
# Out:
#                        geometry               community area_numbe
# 1    POINT (-87.71484 41.85384)          NORTH LAWNDALE         29
# 50   POINT (-87.70541 41.85396)          NORTH LAWNDALE         29
# 124  POINT (-87.72431 41.85373)          NORTH LAWNDALE         29
# 163  POINT (-87.73326 41.85375)          NORTH LAWNDALE         29
# 172  POINT (-87.72431 41.85373)          NORTH LAWNDALE         29
# ..                          ...                     ...        ...
# 284  POINT (-87.67487 41.95452)            NORTH CENTER          5
# 207  POINT (-87.69477 41.85411)          SOUTH LAWNDALE         30
# 287  POINT (-87.69477 41.85411)          SOUTH LAWNDALE         30
# 209  POINT (-87.62572 41.76837)  GREATER GRAND CROSSING         69
# 266  POINT (-87.62572 41.76837)  GREATER GRAND CROSSING         69
#
# [260 rows x 3 columns]

# %%
points_in_community['community'].value_counts()
# Out:
# LOOP                      34
# NEAR WEST SIDE            18
# LAKE VIEW                 18
# NEAR NORTH SIDE           14
# ROGERS PARK               10
# AUSTIN                    10
# UPTOWN                     8
# WEST TOWN                  8
# EAST GARFIELD PARK         8
# EDGEWATER                  8
# NORTH LAWNDALE             8
# LINCOLN SQUARE             8
# LOWER WEST SIDE            8
# GRAND BOULEVARD            8
# ALBANY PARK                6
# IRVING PARK                6
# LOGAN SQUARE               6
# LINCOLN PARK               6
# NEAR SOUTH SIDE            6
# ARMOUR SQUARE              4
# WEST GARFIELD PARK         4
# NORTH CENTER               4
# CHATHAM                    4
# ENGLEWOOD                  4
# OHARE                      4
# WOODLAWN                   4
# FULLER PARK                4
# MCKINLEY PARK              2
# SOUTH LAWNDALE             2
# GARFIELD RIDGE             2
# AVONDALE                   2
# NORWOOD PARK               2
# BRIGHTON PARK              2
# JEFFERSON PARK             2
# WASHINGTON PARK            2
# ROSELAND                   2
# BRIDGEPORT                 2
# DOUGLAS                    2
# WEST ELSDON                2
# GAGE PARK                  2
# WEST ENGLEWOOD             2
# GREATER GRAND CROSSING     2
# Name: community, dtype: int64

# %%
df_bus
# Out:
#        SYSTEMSTOP  OBJECTID                                       the_geom  \
# 0           11953       193   POINT (-87.54862703700002 41.72818418100002)
# 1            2723       194       POINT (-87.737227163 41.749111071000016)
# 2            1307       195  POINT (-87.74397362600001 41.924143016000016)
# 3            6696       196   POINT (-87.65929365400001 41.86931424800002)
# 4              22       197        POINT (-87.72780787099998 41.877006596)
# ...           ...       ...                                            ...
# 11069        7054      7462   POINT (-87.56049104499999 41.76386655599998)
# 11070        6363      7463   POINT (-87.64107999999999 41.87558799999999)
# 11071        8986      7464        POINT (-87.72808945000003 41.966580921)
# 11072       11535      7465   POINT (-87.76675599999999 41.94412799999998)
# 11073        5224      7466        POINT (-87.575941801 41.74602897699998)
#
#                STREET                 CROSS_ST DIR POS   ROUTESSTPG OWLROUTES  \
# 0         92ND STREET                BALTIMORE  EB  NS           95       NaN
# 1         79TH STREET    KILPATRICK (east leg)  EB  NS           79       NaN
# 2           FULLERTON               KILPATRICK  EB  NS           74       NaN
# 3              TAYLOR                   THROOP  EB  NS          157       NaN
# 4             JACKSON                   KARLOV  EB  FS          126       NaN
# ...               ...                      ...  ..  ..          ...       ...
# 11069  S. SHORE DRIVE              73RD STREET  SB  FS         6,26       NaN
# 11070         CLINTON  BLUE LINE (FOREST PARK)  SB  MB  7,37,60,157       N60
# 11071         PULASKI                   LELAND  SB  NT           53       NaN
# 11072         CENTRAL                 CORNELIA  SB  NS           85       NaN
# 11073         JEFFERY              82ND STREET  SB  FS           15       NaN
#
#           CITY  STATUS                    PUBLIC_NAM    POINT_X    POINT_Y
# 0      CHICAGO       1       92nd Street & Baltimore -87.548627  41.728184
# 1      CHICAGO       1      79th Street & Kilpatrick -87.737227  41.749111
# 2      CHICAGO       1        Fullerton & Kilpatrick -87.743974  41.924143
# 3      CHICAGO       1               Taylor & Throop -87.659294  41.869314
# 4      CHICAGO       1              Jackson & Karlov -87.727808  41.877007
# ...        ...     ...                           ...        ...        ...
# 11069  CHICAGO       1  S. Shore Drive & 73rd Street -87.560491  41.763867
# 11070  CHICAGO       1     Clinton Blue Line Station -87.641080  41.875588
# 11071  CHICAGO       1              Pulaski & Leland -87.728089  41.966581
# 11072  CHICAGO       1            Central & Cornelia -87.766756  41.944128
# 11073  CHICAGO       1         Jeffery & 82nd Street -87.575942  41.746029
#
# [10760 rows x 14 columns]

# %%
df_rails
# Out:
#      STOP_ID DIRECTION_ID                      STOP_NAME    STATION_NAME  \
# 0      30082            E            Cicero (Loop-bound)          Cicero
# 1      30151            E      Central Park (Loop-bound)    Central Park
# 2      30184            W   Halsted/63rd (Ashland-bound)         Halsted
# 3      30044            N      Cumberland (O'Hare-bound)      Cumberland
# 4      30092            E          Racine (O'Hare-bound)          Racine
# ..       ...          ...                            ...             ...
# 295    30009            W          Cicero (Harlem-bound)          Cicero
# 296    30259            N        Montrose (O'Hare-bound)        Montrose
# 297    30125            N  North/Clybourn (Howard-bound)  North/Clybourn
# 298    30172            S       O'Hare (Forest Pk-bound)          O'Hare
# 299    30045            S   Cumberland (Forest Pk-bound)      Cumberland
#
#       STATION_DESCRIPTIVE_NAME  MAP_ID    ADA    RED   BLUE      G    BRN  \
# 0           Cicero (Pink Line)   40420   True  False  False  False  False
# 1     Central Park (Pink Line)   40780   True  False  False  False  False
# 2         Halsted (Green Line)   40940   True  False  False   True  False
# 3       Cumberland (Blue Line)   40230   True  False   True  False  False
# 4           Racine (Blue Line)   40470  False  False   True  False  False
# ..                         ...     ...    ...    ...    ...    ...    ...
# 295        Cicero (Green Line)   40480   True  False  False   True  False
# 296       Montrose (Blue Line)   41330  False  False   True  False  False
# 297  North/Clybourn (Red Line)   40650  False   True  False  False  False
# 298         O'Hare (Blue Line)   40890   True  False   True  False  False
# 299     Cumberland (Blue Line)   40230   True  False   True  False  False
#
#          P   Pexp      Y    Pnk      O                     Location  \
# 0    False  False  False   True  False       (41.85182, -87.745336)
# 1    False  False  False   True  False      (41.853839, -87.714842)
# 2    False  False  False  False  False      (41.778943, -87.644244)
# 3    False  False  False  False  False      (41.984246, -87.838028)
# 4    False  False  False  False  False       (41.87592, -87.659458)
# ..     ...    ...    ...    ...    ...                          ...
# 295  False  False  False  False  False      (41.886519, -87.744698)
# 296  False  False  False  False  False      (41.961539, -87.743574)
# 297  False  False  False  False  False      (41.910655, -87.649177)
# 298  False  False  False  False  False  (41.97766526, -87.90422307)
# 299  False  False  False  False  False      (41.984246, -87.838028)
#
#                        Location_Point Community_Area
# 0         POINT (41.85182 -87.745336)           None
# 1        POINT (41.853839 -87.714842)           None
# 2        POINT (41.778943 -87.644244)           None
# 3        POINT (41.984246 -87.838028)           None
# 4         POINT (41.87592 -87.659458)           None
# ..                                ...            ...
# 295      POINT (41.886519 -87.744698)           None
# 296      POINT (41.961539 -87.743574)           None
# 297      POINT (41.910655 -87.649177)           None
# 298  POINT (41.97766526 -87.90422307)           None
# 299      POINT (41.984246 -87.838028)           None
#
# [300 rows x 19 columns]
